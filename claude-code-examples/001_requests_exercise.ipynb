# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.105.2)
# Requirement already satisfied: python-dotenv in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.17)
# Requirement already satisfied: certifi in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages: list, text: str):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages: list, text: str):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

while True:
    user_input = input("> ")
    print(">", user_input)

    add_user_message(messages, user_input)

    answer = chat(messages)

    add_assistant_message(messages, answer)

    print("---")
    print(answer)
    print("---")
# Out:
# > What is 1 + 1?
# ---
# 1 + 1 = 2
# ---
# > how to build a house?
# ---
# # How to Build a House
#
# Here's a basic overview of the main steps:
#
# ## 1. **Planning & Design**
#    - Decide on size, style, and budget
#    - Create or obtain house plans
#    - Get architectural drawings if needed
#
# ## 2. **Land & Legal**
#    - Acquire the property
#    - Obtain building permits
#    - Check zoning laws and regulations
#
# ## 3. **Site Preparation**
#    - Clear and level the land
#    - Mark out the foundation
#    - Set up utilities access
#
# ## 4. **Foundation**
#    - Excavate as needed
#    - Pour concrete foundation
#    - Allow proper curing time
#
# ## 5. **Framing**
#    - Build the wooden frame structure
#    - Install roof trusses
#    - Add wall studs and beams
#
# ## 6. **Exterior**
#    - Install sheathing and wrap
#    - Add roofing materials
#    - Install windows and doors
#
# ## 7. **Utilities**
#    - Run electrical wiring
#    - Install plumbing
#    - Add HVAC systems
#
# ## 8. **Interior**
#    - Install insulation
#    - Add drywall
#    - Paint and flooring
#
# ## 9. **Finishing**
#    - Install fixtures and trim
#    - Landscaping
#    - Final inspections
#
# **Note:** Most people hire contractors for this. Building codes vary by location, so check local requirements first.
# ---
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 9
#       5     print(">", user_input)
#       6
#       7     add_user_message(messages, user_input)
#       8
# ----> 9     answer = chat(messages)
#      10
#      11     add_assistant_message(messages, answer)
#      12
#
# Cell In[4], line 24, in chat(messages, system, temperature, stop_sequences)
#      20
#      21     if system:
#      22         params["system"] = system
#      23
# ---> 24     message = client.messages.create(**params)
#      25     return message.content[0].text
#
# File c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages\anthropic\resources\messages\messages.py:1006, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     999 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1000     warnings.warn(
#    1001         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1002         UserWarning,
#    1003         stacklevel=3,
#    1004     )
# -> 1006 return self._post(
#    1007     "/v1/messages",
#    1008     body=maybe_transform(
#    1009         {
#    1010             "max_tokens": max_tokens,
#    1011             "messages": messages,
#    1012             "model": model,
#    1013             "cache_control": cache_control,
#    1014             "container": container,
#    1015             "inference_geo": inference_geo,
#    1016             "metadata": metadata,
#    1017             "output_config": output_config,
#    1018             "service_tier": service_tier,
#    1019             "stop_sequences": stop_sequences,
#    1020             "stream": stream,
#    1021             "system": system,
#    1022             "temperature": temperature,
#    1023             "thinking": thinking,
#    1024             "tool_choice": tool_choice,
#    1025             "tools": tools,
#    1026             "top_k": top_k,
#    1027             "top_p": top_p,
#    1028         },
#    1029         message_create_params.MessageCreateParamsStreaming
#    1030         if stream
#    1031         else message_create_params.MessageCreateParamsNonStreaming,
#    1032     ),
#    1033     options=make_request_options(
#    1034         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1035     ),
#    1036     cast_to=Message,
#    1037     stream=stream or False,
#    1038     stream_cls=Stream[RawMessageStreamEvent],
#    1039 )
#
# File c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages\anthropic\_base_client.py:1374, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365     warnings.warn(
#    1366         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1367         "Please pass raw bytes via the `content` parameter instead.",
#    1368         DeprecationWarning,
#    1369         stacklevel=2,
#    1370     )
#    1371 opts = FinalRequestOptions.construct(
#    1372     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1373 )
# -> 1374 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\alexandre.nicolas\AppData\Local\Programs\Python\Python314\Lib\site-packages\anthropic\_base_client.py:1147, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1144             err.response.read()
#    1146         log.debug("Re-raising status error")
# -> 1147         raise self._make_status_error_from_response(err.response) from None
#    1149     break
#    1151 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.4: user messages must have non-empty content'}, 'request_id': 'req_011CbX4y4xPaSFhX9kUvRo8g'}
